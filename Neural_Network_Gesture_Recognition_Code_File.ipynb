# %% [markdown]
# # Gesture Recognition
# In this project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.
#
# ## Submission by Satya Prakash

# %%
import numpy as np
import os
from imageio import imread
import cv2
import datetime
import os
from PIL import Image, ImageFilter, ImageEnhance
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
tf.random.set_seed(30)
from keras import backend as K

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
#train_doc = np.random.permutation(open('/datasets/Project_data/train.csv').readlines())
#val_doc = np.random.permutation(open('/datasets/Project_data/val.csv').readlines())
#batch_size = 32
#img_height = 100
#img_width = 100

# %%
# train and validatiaon data creator with ablation
# when ablation is 10, then 10 folders for each label will be selected.
def get_data(path, ablation=None):
    train_doc = np.random.permutation(open(path+'train.csv').readlines())
    val_doc = np.random.permutation(open(path+'val.csv').readlines())
    counts = np.zeros(5) # count for loading folders for 5 classes
    train_data = []
    val_data = []
    # when ablation is None pass full training and val data
    if ablation is not None:
        # iterating train doc
        for doc in train_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                train_data.append(doc)
                counts[lable] += 1 
        counts = np.zeros(5)
        # iterating val doc
        for doc in val_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                val_data.append(doc)
                counts[lable] += 1
    else:
        train_data, val_data = train_doc, val_doc
    return train_data, val_data

# %%
train_doc, val_doc = get_data('/datasets/Project_data/', ablation=None)
batch_size = 32 # experiment with the batch size
enable_augmentation = False # augmentation of Data
# sequence ids
# selecting alternate frames from 7 to 26.
seq_idx = range(7,26,2)
# image dimensions
dim_x, dim_y = 120, 120

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
# generator with augmentation for train data
def generator(source_path, folder_list, batch_size, is_train = False, augmention = False, debug=False):
    # print('\nSource path = ', source_path, '; batch size =', batch_size)
    img_idx = seq_idx #create a list of image numbers you want to use for a particular video
    x = len(img_idx)
    y, z = dim_x, dim_y
    while True:
        # doubling the data for augmentation
        if is_train and augmention:
            t = np.concatenate((np.random.permutation(folder_list), np.random.permutation(folder_list)))
        else:
            t = np.random.permutation(folder_list)
            
        if (len(t)%batch_size) == 0:
            num_batches = int(len(t)/batch_size)
        else:
            num_batches = len(t)//batch_size + 1
            
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                if debug:
                    plt.figure(figsize=(20,5))
                #handling remaining datapoints
                folder_idx = folder + (batch*batch_size)
                if folder_idx >= len(t):
                    break
                folder_str = t[folder_idx]
                imgs = os.listdir(source_path+'/'+ folder_str.split(';')[0]) # read all the images in the folder
                # randomly enabling augmentation and augmentation type
                aug_type = None
                if is_train and augmention and rn.randint(0,1) == 1:
                    aug_type = rn.randint(0, 4) #randomly selecting augmentation type
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ folder_str.strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    # plotting original images for debugging purpose only
                    if debug:
                        plt.subplot(2, x, idx+1)
                        plt.imshow(image.astype('uint8'))

                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    # making the rectangle images into square by cropping sides
                    # so the aspect ration can be mantained while resizing.
                    if image.shape[1] > image.shape[0]:
                        diff_px = image.shape[1] - image.shape[0]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[0]
                        image = image[:, crop_start:crop_end]
                    elif image.shape[0] > image.shape[1]:
                        diff_px = image.shape[0] - image.shape[1]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[1]
                        image = image[:, crop_start:crop_end]

                    #resized_im = imresize(image, size=(y,z))
                    resized_im = cv2.resize(image, dsize=(y,z))
                    if aug_type is not None:
                        if aug_type == 0: # edge Enhancement
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.EDGE_ENHANCE))
                        elif aug_type == 1: # adding gaussian blur
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.GaussianBlur(1)))
                        elif aug_type == 2: # enchancing image detailing
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.DETAIL))
                        elif aug_type == 3: # sharpening image
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.SHARPEN))
                        elif aug_type == 4: # Brightness enhancement
                            resized_im = np.array(ImageEnhance.Brightness((Image.fromarray(resized_im, 'RGB'))).enhance(1.5))
                    # plotting rezised images for debugging purpose only
                    if debug:
                        plt.subplot(2, x, idx+x+1)
                        plt.imshow(resized_im)

                    batch_data[folder,idx,:,:,0] = resized_im[:,:,0]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = resized_im[:,:,1]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = resized_im[:,:,2]/255 #normalise and feed in the image

                batch_labels[folder, int(folder_str.strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = '/datasets/Project_data/train'
val_path = '/datasets/Project_data/val'

#multiply number train seq by 2 when using augmentation
multiplier = 1
if enable_augmentation:
    multiplier = 2
    
num_train_sequences = len(train_doc)*multiplier
print('# training sequences =', num_train_sequences)

num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)

num_epochs = 50 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 50

# %%
# testing generative 
test_gen = generator(train_path, train_doc, 1, is_train = True, augmention = True, debug = True)
d = next(test_gen)[0]

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Bidirectional, BatchNormalization, Activation, Dropout, GlobalAveragePooling2D, GlobalAveragePooling3D, ConvLSTM2D
from keras.layers.convolutional import Conv2D, Conv3D, MaxPooling2D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

#input shape for the st layer
input_shape = (len(seq_idx), dim_x, dim_y, 3)
np.random.seed(30)

# %% [markdown]
# ### Experiment - 1,2,3
# ### TimeDistributed Conv2D + GRU

# %%
'''
model = Sequential()
model.add(TimeDistributed(
    Conv2D(32, (3,3), activation='relu'), input_shape=input_shape)
)
model.add(TimeDistributed(
    MaxPooling2D((2,2)))
)
model.add(BatchNormalization())
model.add(Dropout(0.2))
    
model.add(TimeDistributed(
    Conv2D(64, (3,3), activation='relu'))
)
model.add(TimeDistributed(
    MaxPooling2D((2,2)))
)
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(TimeDistributed(GlobalAveragePooling2D()))
model.add(TimeDistributed(Dense(64, activation='relu')))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(GRU(128))
model.add(BatchNormalization())
model.add(Dense(5, activation='softmax'))

# 21/21 [==============================] - 20s 992ms/step - loss: 0.5789 - categorical_accuracy: 0.7783 - val_loss: 0.4786 - val_categorical_accuracy: 0.6172 - lr: 1.0000e-05
           
'''

# %% [markdown]
# ### Experiment - 4
# ### TimeDistributed Conv2D + Dense

# %%
'''
model = Sequential()
model.add(TimeDistributed(
    Conv2D(32, (3,3), activation='relu'), input_shape=input_shape)
)
model.add(TimeDistributed(
    MaxPooling2D((2,2)))
)
model.add(BatchNormalization())

model.add(TimeDistributed(
    Conv2D(64, (3,3), activation='relu'))
)
model.add(TimeDistributed(
    MaxPooling2D((2,2)))
)
model.add(BatchNormalization())

model.add(TimeDistributed(
    Conv2D(128, (3,3), activation='relu'))
)
model.add(TimeDistributed(
    MaxPooling2D((2,2)))
)
model.add(BatchNormalization())

model.add(GlobalAveragePooling3D())
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(5, activation='softmax'))

# loss: 0.6426 - categorical_accuracy: 0.7292 - val_loss: 0.4727 - val_categorical_accuracy: 0.8359 - lr: 1.0000e-05
'''

# %% [markdown]
# ### Experiment - 5
# ### TimeDistributed + ConvLSTM2D

# %%
'''
model = Sequential()
model.add(TimeDistributed(
    Conv2D(8, (3,3), activation='relu'), input_shape=input_shape)
)
model.add(BatchNormalization())
model.add(TimeDistributed(
    Conv2D(16, (3,3), activation='relu'))
)
model.add(BatchNormalization())
model.add(
    ConvLSTM2D(8, kernel_size = 3, return_sequences=False)
)
model.add(BatchNormalization())
model.add(TimeDistributed(
    Dense(64, activation='relu'))
)
model.add(BatchNormalization())
model.add(GlobalAveragePooling2D())
model.add(Dense(64, activation='relu'))
model.add(Dense(5, activation='softmax'))
'''
# Out:
# 2024-06-05 02:56:09.385357: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-06-05 02:56:09.385434: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14800 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:1d:00.0, compute capability: 7.5

# %% [markdown]
# ### Experiment - 6
# ### Conv3D

# %%
model = Sequential()

model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
model.add(Conv3D(64, kernel_size=3, activation='relu'))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))

model.add(Conv3D(128, kernel_size=3, activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))

model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))

model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 7
# ### Conv3D with BatchNormalization, Dropout,Flatten

# %%
model = Sequential()

model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
model.add(Conv3D(64, kernel_size=3, activation='relu'))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv3D(128, kernel_size=3, activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 8
# ### Conv3D with BatchNormalization, Dropout, GlobalAveragePooling3D

# %%
model = Sequential()

model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
model.add(Conv3D(64, kernel_size=3, activation='relu'))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv3D(128, kernel_size=3, activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(GlobalAveragePooling3D())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 9&10
# ### Conv3D with BatchNormalization, Dropout,Flatten -> increased dropout

# %%
model = Sequential()

model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
model.add(Conv3D(64, kernel_size=3, activation='relu'))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv3D(128, kernel_size=3, activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
model.add(MaxPooling3D(pool_size=(1, 2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Final Model

# %%
model = Sequential()
model.add(TimeDistributed(
    Conv2D(8, (3,3), activation='relu'), input_shape=input_shape)
)
model.add(BatchNormalization())
model.add(TimeDistributed(
    Conv2D(16, (3,3), activation='relu'))
)
model.add(BatchNormalization())
model.add(
    ConvLSTM2D(8, kernel_size = 3, return_sequences=False)
)
model.add(BatchNormalization())
model.add(TimeDistributed(
    Dense(64, activation='relu'))
)
model.add(BatchNormalization())
model.add(GlobalAveragePooling2D())
model.add(Dense(64, activation='relu'))
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = tf.keras.optimizers.Adam(lr=0.01) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_9 (TimeDis  (None, 10, 118, 118, 8)  224
#  tributed)
#
#  batch_normalization_12 (Bat  (None, 10, 118, 118, 8)  32
#  chNormalization)
#
#  time_distributed_10 (TimeDi  (None, 10, 116, 116, 16)  1168
#  stributed)
#
#  batch_normalization_13 (Bat  (None, 10, 116, 116, 16)  64
#  chNormalization)
#
#  conv_lstm2d_3 (ConvLSTM2D)  (None, 114, 114, 8)       6944
#
#  batch_normalization_14 (Bat  (None, 114, 114, 8)      32
#  chNormalization)
#
#  time_distributed_11 (TimeDi  (None, 114, 114, 64)     576
#  stributed)
#
#  batch_normalization_15 (Bat  (None, 114, 114, 64)     256
#  chNormalization)
#
#  global_average_pooling2d_3   (None, 64)               0
#  (GlobalAveragePooling2D)
#
#  dense_10 (Dense)            (None, 64)                4160
#
#  dense_11 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 13,781
# Trainable params: 13,589
# Non-trainable params: 192
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'Mythili_ConvLSTM2D' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=1, mode='min', min_delta=0.0001, cooldown=0, min_lr=0.00001)
callbacks_list = [checkpoint, LR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                        callbacks=callbacks_list, validation_data=val_generator, 
                        validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/50
# 21/21 [==============================] - ETA: 0s - loss: 1.4078 - categorical_accuracy: 0.3318
# Epoch 00001: val_loss improved from inf to 1.49158, saving model to Mythili_ConvLSTM2D_2024-06-0502_55_48.468157/model-00001-1.40780-0.33185-1.49158-0.17188.h5
# 21/21 [==============================] - 25s 1s/step - loss: 1.4078 - categorical_accuracy: 0.3318 - val_loss: 1.4916 - val_categorical_accuracy: 0.1719 - lr: 0.0100
# Epoch 2/50
# 21/21 [==============================] - ETA: 0s - loss: 1.2144 - categorical_accuracy: 0.4449
# Epoch 00002: val_loss did not improve from 1.49158
# 21/21 [==============================] - 22s 1s/step - loss: 1.2144 - categorical_accuracy: 0.4449 - val_loss: 1.7266 - val_categorical_accuracy: 0.1484 - lr: 0.0100
# Epoch 3/50
# 21/21 [==============================] - ETA: 0s - loss: 1.1474 - categorical_accuracy: 0.4688
# Epoch 00003: val_loss did not improve from 1.49158
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 21/21 [==============================] - 21s 1s/step - loss: 1.1474 - categorical_accuracy: 0.4688 - val_loss: 2.2447 - val_categorical_accuracy: 0.1406 - lr: 0.0100
# Epoch 4/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0746 - categorical_accuracy: 0.5193
# Epoch 00004: val_loss did not improve from 1.49158
# 21/21 [==============================] - 21s 1s/step - loss: 1.0746 - categorical_accuracy: 0.5193 - val_loss: 1.9061 - val_categorical_accuracy: 0.1250 - lr: 1.0000e-03
# Epoch 5/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9928 - categorical_accuracy: 0.5476
# Epoch 00005: val_loss did not improve from 1.49158
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# 21/21 [==============================] - 21s 1s/step - loss: 0.9928 - categorical_accuracy: 0.5476 - val_loss: 1.6716 - val_categorical_accuracy: 0.1328 - lr: 1.0000e-03
# Epoch 6/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9775 - categorical_accuracy: 0.5417
# Epoch 00006: val_loss did not improve from 1.49158
# 21/21 [==============================] - 21s 1s/step - loss: 0.9775 - categorical_accuracy: 0.5417 - val_loss: 1.5288 - val_categorical_accuracy: 0.1484 - lr: 1.0000e-04
# Epoch 7/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9671 - categorical_accuracy: 0.5387
# Epoch 00007: val_loss improved from 1.49158 to 1.36649, saving model to Mythili_ConvLSTM2D_2024-06-0502_55_48.468157/model-00007-0.96706-0.53869-1.36649-0.18750.h5
# 21/21 [==============================] - 22s 1s/step - loss: 0.9671 - categorical_accuracy: 0.5387 - val_loss: 1.3665 - val_categorical_accuracy: 0.1875 - lr: 1.0000e-04
# Epoch 8/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9711 - categorical_accuracy: 0.5417
# Epoch 00008: val_loss improved from 1.36649 to 1.34007, saving model to Mythili_ConvLSTM2D_2024-06-0502_55_48.468157/model-00008-0.97107-0.54167-1.34007-0.16406.h5
# 21/21 [==============================] - 21s 1s/step - loss: 0.9711 - categorical_accuracy: 0.5417 - val_loss: 1.3401 - val_categorical_accuracy: 0.1641 - lr: 1.0000e-04
# Epoch 9/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9410 - categorical_accuracy: 0.5670
# Epoch 00010: val_loss improved from 1.26855 to 1.21313, saving model to Mythili_ConvLSTM2D_2024-06-0502_55_48.468157/model-00010-0.94102-0.56696-1.21313-0.21875.h5
# 21/21 [==============================] - 22s 1s/step - loss: 0.9410 - categorical_accuracy: 0.5670 - val_loss: 1.2131 - val_categorical_accuracy: 0.2188 - lr: 1.0000e-04
# Epoch 11/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9585 - categorical_accuracy: 0.5506
# Epoch 00011: val_loss did not improve from 1.21313
# 21/21 [==============================] - 21s 1s/step - loss: 0.9585 - categorical_accuracy: 0.5506 - val_loss: 1.2297 - val_categorical_accuracy: 0.2578 - lr: 1.0000e-04
# Epoch 12/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9385 - categorical_accuracy: 0.5625
# Epoch 00012: val_loss improved from 1.21313 to 1.21104, saving model to Mythili_ConvLSTM2D_2024-06-0502_55_48.468157/model-00012-0.93849-0.56250-1.21104-0.28125.h5
# 21/21 [==============================] - 20s 1s/step - loss: 0.9385 - categorical_accuracy: 0.5625 - val_loss: 1.2110 - val_categorical_accuracy: 0.2812 - lr: 1.0000e-04
# Epoch 13/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9329 - categorical_accuracy: 0.5714
# Epoch 00013: val_loss improved from 1.21104 to 1.20985, saving model to Mythili_ConvLSTM2D_2024-06-0502_55_48.468157/model-00013-0.93288-0.57143-1.20985-0.30469.h5
# 21/21 [==============================] - 21s 1s/step - loss: 0.9329 - categorical_accuracy: 0.5714 - val_loss: 1.2098 - val_categorical_accuracy: 0.3047 - lr: 1.0000e-04
# Epoch 14/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9476 - categorical_accuracy: 0.5655
# Epoch 00014: val_loss improved from 1.20985 to 1.16375, saving model to Mythili_ConvLSTM2D_2024-06-0502_55_48.468157/model-00014-0.94758-0.56548-1.16375-0.28906.h5
# 21/21 [==============================] - 21s 1s/step - loss: 0.9476 - categorical_accuracy: 0.5655 - val_loss: 1.1637 - val_categorical_accuracy: 0.2891 - lr: 1.0000e-04
# Epoch 15/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9267 - categorical_accuracy: 0.5625
# Epoch 00015: val_loss improved from 1.16375 to 1.15317, saving model to Mythili_ConvLSTM2D_2024-06-0502_55_48.468157/model-00015-0.92666-0.56250-1.15317-0.27344.h5
# 21/21 [==============================] - 21s 1s/step - loss: 0.9267 - categorical_accuracy: 0.5625 - val_loss: 1.1532 - val_categorical_accuracy: 0.2734 - lr: 1.0000e-04
# Epoch 16/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9412 - categorical_accuracy: 0.5774
# Epoch 00016: val_loss did not improve from 1.15317
# 21/21 [==============================] - 20s 969ms/step - loss: 0.9412 - categorical_accuracy: 0.5774 - val_loss: 1.1783 - val_categorical_accuracy: 0.3125 - lr: 1.0000e-04
# Epoch 17/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9331 - categorical_accuracy: 0.5699
# Epoch 00017: val_loss improved from 1.15317 to 1.14624, saving model to Mythili_ConvLSTM2D_2024-06-0502_55_48.468157/model-00017-0.93307-0.56994-1.14624-0.30469.h5
# 21/21 [==============================] - 21s 1s/step - loss: 0.9331 - categorical_accuracy: 0.5699 - val_loss: 1.1462 - val_categorical_accuracy: 0.3047 - lr: 1.0000e-04
# Epoch 18/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9111 - categorical_accuracy: 0.5774
# Epoch 00018: val_loss improved from 1.14624 to 1.05826, saving model to Mythili_ConvLSTM2D_2024-06-0502_55_48.468157/model-00018-0.91110-0.57738-1.05826-0.33594.h5
# 21/21 [==============================] - 21s 1s/step - loss: 0.9111 - categorical_accuracy: 0.5774 - val_loss: 1.0583 - val_categorical_accuracy: 0.3359 - lr: 1.0000e-04
# Epoch 19/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9272 - categorical_accuracy: 0.5655
# Epoch 00019: val_loss did not improve from 1.05826
# 21/21 [==============================] - 21s 1s/step - loss: 0.9272 - categorical_accuracy: 0.5655 - val_loss: 1.0730 - val_categorical_accuracy: 0.2891 - lr: 1.0000e-04
# Epoch 20/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9016 - categorical_accuracy: 0.5714
# Epoch 00020: val_loss improved from 1.05826 to 1.03930, saving model to Mythili_ConvLSTM2D_2024-06-0502_55_48.468157/model-00020-0.90159-0.57143-1.03930-0.51562.h5
# 21/21 [==============================] - 20s 981ms/step - loss: 0.9016 - categorical_accuracy: 0.5714 - val_loss: 1.0393 - val_categorical_accuracy: 0.5156 - lr: 1.0000e-04
# Epoch 21/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8883 - categorical_accuracy: 0.5967
# Epoch 00031: val_loss improved from 0.75515 to 0.74454, saving model to Mythili_ConvLSTM2D_2024-06-0502_55_48.468157/model-00031-0.88828-0.59673-0.74454-0.69531.h5
# 21/21 [==============================] - 21s 1s/step - loss: 0.8883 - categorical_accuracy: 0.5967 - val_loss: 0.7445 - val_categorical_accuracy: 0.6953 - lr: 1.0000e-05
# Epoch 32/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8830 - categorical_accuracy: 0.5818
# Epoch 00032: val_loss improved from 0.74454 to 0.71476, saving model to Mythili_ConvLSTM2D_2024-06-0502_55_48.468157/model-00032-0.88301-0.58185-0.71476-0.69531.h5
# 21/21 [==============================] - 20s 978ms/step - loss: 0.8830 - categorical_accuracy: 0.5818 - val_loss: 0.7148 - val_categorical_accuracy: 0.6953 - lr: 1.0000e-05
# Epoch 33/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8889 - categorical_accuracy: 0.5967
# Epoch 00033: val_loss did not improve from 0.71476
# 21/21 [==============================] - 21s 1s/step - loss: 0.8889 - categorical_accuracy: 0.5967 - val_loss: 0.7178 - val_categorical_accuracy: 0.7031 - lr: 1.0000e-05
# Epoch 34/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8764 - categorical_accuracy: 0.5744
# Epoch 00034: val_loss did not improve from 0.71476
# 21/21 [==============================] - 21s 1s/step - loss: 0.8764 - categorical_accuracy: 0.5744 - val_loss: 0.7211 - val_categorical_accuracy: 0.6797 - lr: 1.0000e-05
# Epoch 35/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8948 - categorical_accuracy: 0.5863
# Epoch 00035: val_loss improved from 0.71476 to 0.69572, saving model to Mythili_ConvLSTM2D_2024-06-0502_55_48.468157/model-00035-0.89476-0.58631-0.69572-0.70312.h5
# 21/21 [==============================] - 21s 1s/step - loss: 0.8948 - categorical_accuracy: 0.5863 - val_loss: 0.6957 - val_categorical_accuracy: 0.7031 - lr: 1.0000e-05
# Epoch 36/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9040 - categorical_accuracy: 0.5670
# Epoch 00036: val_loss did not improve from 0.69572
# 21/21 [==============================] - 20s 993ms/step - loss: 0.9040 - categorical_accuracy: 0.5670 - val_loss: 0.7003 - val_categorical_accuracy: 0.7109 - lr: 1.0000e-05
# Epoch 37/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8789 - categorical_accuracy: 0.5848
# Epoch 00037: val_loss did not improve from 0.69572
# 21/21 [==============================] - 21s 1s/step - loss: 0.8789 - categorical_accuracy: 0.5848 - val_loss: 0.7041 - val_categorical_accuracy: 0.6953 - lr: 1.0000e-05
# Epoch 38/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8992 - categorical_accuracy: 0.5804
# Epoch 00038: val_loss did not improve from 0.69572
# 21/21 [==============================] - 22s 1s/step - loss: 0.8992 - categorical_accuracy: 0.5804 - val_loss: 0.7272 - val_categorical_accuracy: 0.6797 - lr: 1.0000e-05
# Epoch 39/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8937 - categorical_accuracy: 0.5759
# Epoch 00039: val_loss improved from 0.69572 to 0.65681, saving model to Mythili_ConvLSTM2D_2024-06-0502_55_48.468157/model-00039-0.89370-0.57589-0.65681-0.72656.h5
# 21/21 [==============================] - 21s 1s/step - loss: 0.8937 - categorical_accuracy: 0.5759 - val_loss: 0.6568 - val_categorical_accuracy: 0.7266 - lr: 1.0000e-05
# Epoch 40/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8674 - categorical_accuracy: 0.5833
# Epoch 00040: val_loss did not improve from 0.65681
# 21/21 [==============================] - 21s 1s/step - loss: 0.8674 - categorical_accuracy: 0.5833 - val_loss: 0.7165 - val_categorical_accuracy: 0.6875 - lr: 1.0000e-05
# Epoch 41/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8804 - categorical_accuracy: 0.5997
# Epoch 00041: val_loss did not improve from 0.65681
# 21/21 [==============================] - 21s 1s/step - loss: 0.8804 - categorical_accuracy: 0.5997 - val_loss: 0.6982 - val_categorical_accuracy: 0.7031 - lr: 1.0000e-05
# Epoch 42/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8736 - categorical_accuracy: 0.5908
# Epoch 00042: val_loss did not improve from 0.65681
# 21/21 [==============================] - 20s 987ms/step - loss: 0.8736 - categorical_accuracy: 0.5908 - val_loss: 0.6861 - val_categorical_accuracy: 0.7109 - lr: 1.0000e-05
# Epoch 43/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8849 - categorical_accuracy: 0.5759
# Epoch 00043: val_loss did not improve from 0.65681
# 21/21 [==============================] - 21s 1s/step - loss: 0.8849 - categorical_accuracy: 0.5759 - val_loss: 0.6882 - val_categorical_accuracy: 0.6797 - lr: 1.0000e-05
# Epoch 44/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9048 - categorical_accuracy: 0.5818
# Epoch 00044: val_loss did not improve from 0.65681
# 21/21 [==============================] - 20s 983ms/step - loss: 0.9048 - categorical_accuracy: 0.5818 - val_loss: 0.6971 - val_categorical_accuracy: 0.6953 - lr: 1.0000e-05
# Epoch 45/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8799 - categorical_accuracy: 0.6027
# Epoch 00045: val_loss did not improve from 0.65681
# 21/21 [==============================] - 21s 1s/step - loss: 0.8799 - categorical_accuracy: 0.6027 - val_loss: 0.6953 - val_categorical_accuracy: 0.7031 - lr: 1.0000e-05
# Epoch 46/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8752 - categorical_accuracy: 0.5863
# Epoch 00046: val_loss did not improve from 0.65681
# 21/21 [==============================] - 21s 1s/step - loss: 0.8752 - categorical_accuracy: 0.5863 - val_loss: 0.7238 - val_categorical_accuracy: 0.6719 - lr: 1.0000e-05
# Epoch 47/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8612 - categorical_accuracy: 0.5923
# Epoch 00047: val_loss improved from 0.65681 to 0.65159, saving model to Mythili_ConvLSTM2D_2024-06-0502_55_48.468157/model-00047-0.86120-0.59226-0.65159-0.74219.h5
# 21/21 [==============================] - 22s 1s/step - loss: 0.8612 - categorical_accuracy: 0.5923 - val_loss: 0.6516 - val_categorical_accuracy: 0.7422 - lr: 1.0000e-05
# Epoch 48/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8868 - categorical_accuracy: 0.5893
# Epoch 00048: val_loss did not improve from 0.65159
# 21/21 [==============================] - 21s 1s/step - loss: 0.8868 - categorical_accuracy: 0.5893 - val_loss: 0.7013 - val_categorical_accuracy: 0.7031 - lr: 1.0000e-05
# Epoch 49/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8710 - categorical_accuracy: 0.5863
# Epoch 00049: val_loss did not improve from 0.65159
# 21/21 [==============================] - 21s 1s/step - loss: 0.8710 - categorical_accuracy: 0.5863 - val_loss: 0.6937 - val_categorical_accuracy: 0.7031 - lr: 1.0000e-05
# Epoch 50/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8767 - categorical_accuracy: 0.5833
# Epoch 00050: val_loss did not improve from 0.65159
# 21/21 [==============================] - 21s 1s/step - loss: 0.8767 - categorical_accuracy: 0.5833 - val_loss: 0.7073 - val_categorical_accuracy: 0.7109 - lr: 1.0000e-05

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(121)
ax1 = plt.plot(history.history['loss'])
ax1 = plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
ax2 = plt.subplot(122)
ax2 = plt.plot(history.history['categorical_accuracy'])
ax2 = plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('categorical_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
